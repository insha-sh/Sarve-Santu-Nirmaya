# %% [markdown]
# # Data Pre-processing

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_excel('Healthcare_Workers.xlsx', 'Sheet2')

# %%
dataset.head()
# Out:
#    AGE  GENDER      EDUCATION        OCCUPATION MAR_STATUS FAM_TYPE  CHILDREN  \
# 0   31    Male            SSC  Ambulance Driver     Single    Alone         0
# 1   24    Male      Below SSC          Ward-boy     Single    Joint         0
# 2   50    Male      Below SSC          Ward-boy    Married    Joint         1
# 3   25  Female  Post Graduate             Nurse    Married  Nuclear         1
# 4   25  Female       Graduate             Nurse     Single  Nuclear         0
#
#    ELDERS  CHRONIC    LIVING_CONDITIONS  ...  SLEEP_HOURS_24  FEAR_SCORE  \
# 0       1        0       Without family  ...             4.5          11
# 1       0        1  With family at home  ...             5.0          29
# 2       1        0       Without family  ...             6.0          22
# 3       0        0  With family at home  ...             5.0          10
# 4       0        0       Without family  ...             6.0          13
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   AGE                              68 non-null     int64
#  1   GENDER                           68 non-null     object
#  2   EDUCATION                        68 non-null     object
#  3   OCCUPATION                       68 non-null     object
#  4   MAR_STATUS                       68 non-null     object
#  5   FAM_TYPE                         68 non-null     object
#  6   CHILDREN                         68 non-null     int64
#  7   ELDERS                           68 non-null     int64
#  8   CHRONIC                          68 non-null     int64
#  9   LIVING_CONDITIONS                68 non-null     object
#  10  TRAVEL_MIN                       68 non-null     int64
#  11  WORK_HOURS                       68 non-null     int64
# ...

# %%
dataset = dataset.astype({'CHILDREN': 'object',
                          'ELDERS' : 'object',
                          'CHRONIC' : 'object',
                          'MEALS_SKIP' : 'object', 
                          'DEATHS_FAMILY' :'object',
                          'REASON_FAM_DEATH_COVID' : 'object',
                          'MENTAL_HEALTH_MEDS_BEFORE_COVID' : 'object',
                         'DEATHS_WORK' : 'object'})

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   AGE                              68 non-null     int64
#  1   GENDER                           68 non-null     object
#  2   EDUCATION                        68 non-null     object
#  3   OCCUPATION                       68 non-null     object
#  4   MAR_STATUS                       68 non-null     object
#  5   FAM_TYPE                         68 non-null     object
#  6   CHILDREN                         68 non-null     object
#  7   ELDERS                           68 non-null     object
#  8   CHRONIC                          68 non-null     object
#  9   LIVING_CONDITIONS                68 non-null     object
#  10  TRAVEL_MIN                       68 non-null     int64
#  11  WORK_HOURS                       68 non-null     int64
# ...

# %%
dataset.describe()
# Out:
#              AGE  TRAVEL_MIN  WORK_HOURS  HOLIDAY_MONTH  SLEEP_HOURS_24  \
# count  68.000000   68.000000   68.000000      68.000000       68.000000
# mean   38.191176   85.514706   10.779412       3.014706        6.235294
# std    10.958888   78.664884    4.006881       2.898752        1.756588
# min    22.000000    5.000000    1.000000       0.000000        3.000000
# 25%    26.750000   60.000000    8.000000       0.000000        5.000000
# 50%    38.000000   60.000000   12.000000       4.000000        6.000000
# 75%    46.250000   97.500000   13.250000       4.000000        7.000000
# max    63.000000  360.000000   20.000000      15.000000       15.000000
#
#        FEAR_SCORE  ANXIETY_SCORE  PTSD_SCORE
# count   68.000000      68.000000   68.000000
# mean    20.676471      24.735294   20.602941
# std      6.991340      20.247438   15.740564
# min      7.000000       0.000000    0.000000
# 25%     14.000000       5.000000    6.000000
# 50%     21.000000      23.000000   18.500000
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.set_theme(style = "darkgrid", rc= {"axes.facecolor": ".3",'grid.linewidth': 0.1, })

plt.figure(figsize = (20,10))

plt.subplot(2,4,1)
sns.histplot(data = dataset, x = 'AGE', color = 'White', stat = 'density', kde = True)

plt.subplot(2,4,2)
sns.histplot(data = dataset, x = 'TRAVEL_MIN', color = 'White', stat = 'density', kde = True,
            binwidth = 30)

plt.subplot(2,4,3)
sns.histplot(data = dataset, x = 'WORK_HOURS', color = 'White', stat = 'density', kde = True)

plt.subplot(2,4,4)
sns.histplot(data = dataset, x = 'HOLIDAY_MONTH', color = 'White', stat = 'density', kde = True)

plt.subplot(2,4,5)
sns.histplot(data = dataset, x = 'SLEEP_HOURS_24', color = 'White', stat = 'density', kde = True)

plt.subplot(2,4,6)
sns.histplot(data = dataset, x = 'FEAR_SCORE', color = 'White', stat = 'density', kde = True)

plt.subplot(2,4,7)
sns.histplot(data = dataset, x = 'ANXIETY_SCORE', color = 'White', stat = 'density', kde = True)

plt.subplot(2,4,8)
sns.histplot(data = dataset, x = 'PTSD_SCORE', color = 'White', stat = 'density', kde = True)
# Out:
# <AxesSubplot:xlabel='PTSD_SCORE', ylabel='Density'>

# %%
sns.set_theme(style = "darkgrid", rc= {"axes.facecolor": ".9",'grid.linewidth': 0.9, }, palette = 'deep')

plt.figure(figsize = (20,20))

plt.subplot(3,3,1)
sns.countplot(data = dataset, x = 'GENDER')

plt.subplot(3,3,2)
sns.countplot(data = dataset, x = 'CHILDREN')

plt.subplot(3,3,3)
sns.countplot(data = dataset, x = 'OCCUPATION')

plt.subplot(3,3,4)
sns.countplot(data = dataset, x = 'MAR_STATUS')

plt.subplot(3,3,5)
sns.countplot(data = dataset, x = 'FAM_TYPE')

plt.subplot(3,3,6)
sns.countplot(data = dataset, x = 'LIVING_CONDITIONS')
# Out:
# <AxesSubplot:xlabel='LIVING_CONDITIONS', ylabel='count'>

# %%
sns.set_theme(style = "darkgrid", rc= {"axes.facecolor": ".9",'grid.linewidth': 0.9, }, palette = 'husl')

plt.figure(figsize = (30,30))

plt.subplot(4,4,1)
sns.barplot(data = dataset, x = 'GENDER', y = 'ANXIETY_SCORE')

plt.subplot(4,4,2)
sns.barplot(data = dataset, x = 'CHILDREN', y = 'ANXIETY_SCORE')

plt.subplot(4,4,3)
sns.barplot(data = dataset, x = 'OCCUPATION', y = 'ANXIETY_SCORE')

plt.subplot(4,4,4)
sns.barplot(data = dataset, x = 'MAR_STATUS', y = 'ANXIETY_SCORE')

plt.subplot(4,4,5)
sns.barplot(data = dataset, x = 'FAM_TYPE', y = 'ANXIETY_SCORE')

plt.subplot(4,4,6)
sns.barplot(data = dataset, x = 'LIVING_CONDITIONS', y = 'ANXIETY_SCORE')

plt.subplot(4,4,6)
sns.barplot(data = dataset, x = 'ELDERS', y = 'ANXIETY_SCORE')

plt.subplot(4,4,7)
sns.barplot(data = dataset, x = 'CHRONIC', y = 'ANXIETY_SCORE')

plt.subplot(4,4,8)
sns.barplot(data = dataset, x = 'MEALS_SKIP', y = 'ANXIETY_SCORE')

plt.subplot(4,4,9)
sns.barplot(data = dataset, x = 'DEATHS_FAMILY', y = 'ANXIETY_SCORE')

plt.subplot(4,4,10)
sns.barplot(data = dataset, x = 'EDUCATION', y = 'ANXIETY_SCORE')
plt.xticks(rotation = 45)

plt.subplot(4,4,11)
sns.barplot(data = dataset, x = 'REASON_FAM_DEATH_COVID', y = 'ANXIETY_SCORE', )

plt.subplot(4,4,12)
sns.barplot(data = dataset, x = 'MENTAL_HEALTH_MEDS_BEFORE_COVID', y = 'ANXIETY_SCORE')
# Out:
# <AxesSubplot:xlabel='MENTAL_HEALTH_MEDS_BEFORE_COVID', ylabel='ANXIETY_SCORE'>

# %%
# Advanced statistical methods
grid = sns.PairGrid(data = dataset[['AGE',
                          'TRAVEL_MIN',
                          'WORK_HOURS',
                          'HOLIDAY_MONTH',
                          'SLEEP_HOURS_24',
                          'FEAR_SCORE',
                          'ANXIETY_SCORE',
                          'PTSD_SCORE']], )
grid.map(sns.scatterplot)

# %%
plt.figure(figsize = (10,7))

sns.heatmap(dataset.corr(method = "kendall"), annot = True, cmap='magma')
# Out:
# <AxesSubplot:>

# %%
#Alone and nuclear

alone_dataset = dataset[dataset['FAM_TYPE'] == 'Alone']
nuclear_dataset = dataset[dataset['FAM_TYPE'] == 'Nuclear']

plt.figure(figsize = (30,10))

plt.subplot(1,2,1)
sns.heatmap(alone_dataset.corr(method = "kendall"), annot = True, cmap="magma")
plt.title('FAMILY TYPE - ALONE')

plt.subplot(1,2,2)
sns.heatmap(nuclear_dataset.corr(method = "kendall"), annot = True,cmap="magma")
plt.title("FAMILY TYPE - NUCLEAR")
# Out:
# Text(0.5, 1.0, 'FAMILY TYPE - NUCLEAR')

# %%
#Male and Female

male_dataset = dataset[dataset['GENDER'] == 'Male']
female_dataset = dataset[dataset['GENDER'] == 'Female']

plt.figure(figsize = (30,10))

plt.subplot(1,2,1)
sns.heatmap(male_dataset.corr(method = "kendall"), annot = True, cmap="magma")
plt.title('GENDER - MALE')

plt.subplot(1,2,2)
sns.heatmap(female_dataset.corr(method = "kendall"), annot = True,cmap="magma")
plt.title("GENDER - FEMALE")
# Out:
# Text(0.5, 1.0, 'GENDER - FEMALE')

# %%
#Family with kids vs without

childno_dataset = dataset[dataset['CHILDREN'] == 0]
childyes_dataset = dataset[dataset['CHILDREN'] == 1]

plt.figure(figsize = (30,10))

plt.subplot(1,2,1)
sns.heatmap(childno_dataset.corr(method = "kendall"), annot = True, cmap="magma")
plt.title('Individuals without kids at home')

plt.subplot(1,2,2)
sns.heatmap(childyes_dataset.corr(method = "kendall"), annot = True,cmap="magma")
plt.title("Individuals with kids at home")
# Out:
# Text(0.5, 1.0, 'Individuals with kids at home')

# %%
#Family with kids vs without

chronicno_dataset = dataset[dataset['CHRONIC'] == 0]
chronicyes_dataset = dataset[dataset['CHRONIC'] == 1]

plt.figure(figsize = (30,10))

plt.subplot(1,2,1)
sns.heatmap(chronicno_dataset.corr(method = "kendall"), annot = True, cmap="magma")
plt.title('Individuals without Chronic illness family members at home')

plt.subplot(1,2,2)
sns.heatmap(chronicyes_dataset.corr(method = "kendall"), annot = True,cmap="magma")
plt.title('Individuals with Chronic illness family members at home')
# Out:
# Text(0.5, 1.0, 'Individuals with Chronic illness family members at home')
